# %%
import pandas as pd

# %%
data = pd.read_json("rev2.json")

# %%
data
# Out:
#           asin                                               text  \
# 0   B07JQNB7QG                                 Better then others
# 1   B07JQNB7QG                                             Thanks
# 2   B07JQNB7QG  Taste is very good. This feels spicy which is ...
# 3   B07JQNB7QG                                          पैसा वसूल
# 4   B07JQNB7QG                                       Good quality
# ..         ...                                                ...
# 95  B07JQNB7QG                  this has great taste and texture.
# 96  B07JQNB7QG  The flavorur is completely different from norm...
# 97  B07JQNB7QG                                    Value for money
# 98  B07JQNB7QG  Different from the usual Maggi which everyone ...
# 99  B07JQNB7QG  The flavour was great. I loved this masala fla...
#
#                                             title  \
# 0                                            Good
# 1                                          Thanks
# ...

# %%
data = data.drop_duplicates(subset='text')

# %%
len(data)
# Out:
# 99

# %%
data
# Out:
#          asin                                               text  \
# 0  B07JQNB7QG                                 Better then others
# 1  B07JQNB7QG                                             Thanks
# 2  B07JQNB7QG  Taste is very good. This feels spicy which is ...
# 3  B07JQNB7QG                                       Good quality
# 4  B07JQNB7QG                                  Very Good product
# 5  B07JQNB7QG                                          Good Test
# 6  B07JQNB7QG                                         Very good👍
# 7  B07JQNB7QG  Not recommended for kids as it's spicier than ...
# 8  B07JQNB7QG                                    Excellent taste
# 9  B07JQNB7QG  Tasty ! Sorry to Say But Avoid Eating Maggi Ul...
#
#                                                title  \
# 0                                               Good
# 1                                             Thanks
# 2                                      Awasome taste
# ...
